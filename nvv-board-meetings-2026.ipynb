# %% [markdown]
# # 2026 NVV Board Meetings
#
# ## Monday, January 12th, 2026 - Shell Amsterdam - Minutes
#
# - Present: Stefano Mania, Christine Bertrand and Domenico Lahaye
# - Excused: Anna Felden
#
# ### 1/ Composition of the New Board Starting January 2026
#
# - Stefano Mania - Chair (replaces Rob Bastiaans)
# - Anna Felden - Treasurer (replaces Ivan Langella)
# - Domenico Lahaye - Secretary (second term)
# - Christine Bertrand - Outreach (replace Xiaocheng Ming)
#
# ### 2/ Registration of new board members at the Kamer van Koophandel
#
# To do: Stefano, Christine, Anna: register online using DIGID at [provide link to kvk website].
#
# ### 3/ Securing NVV Financial Reserves
#
# Invest approximately EUR 50k (fifty thousand) in long term fund to protect against devaluation.
# Impact on taxes (to be paid to the Dutch state) and management of the fund (to be paid to ING Bank) to be investigated further.
#
# To do: Stefanio will take to tax advisor in February.
#
# ### 4/ Combura2026 - 2027
#
# Possible location: Shell Amsterdam - be advised of higher fees for accommodation.
#
# To do: collect list of attendees of past editions;
#
# ### 5/ Outreach: Website NNV and Website Combura
#
# Static background info as Wikipedia page. News via LinkedInn page.
#
# ### 6/ Outreach - Industrial Membership of NVV
#
# List potential members
# What to offer to new members
#
# ### 7/ How to position link with Dutch Section of the Combustion Institute, IFRF, other national committees, ASME and other parties?
#
# How to take advantage of each others networks and activities? How to be complementary to existing initiatives (e.g. TOTEM, INFUB).
#
# ### 8/ Forthcoming NVV Board Meeting
#
# To do: establish date and location.
