# %% [markdown]
# # 2026 NVV Board Meetings
#
# ## Monday, January 12th, 2026 - Shell Amsterdam - Minutes
#
# - Present: Stefano Mania, Christine Bertrand and Domenico Lahaye
# - Excused: Anna Felden
#
# ### 1/ Composition of the New Board Starting January 2026
#
# - Stefano Mania - Chair (replaces Rob Bastiaans)
# - Anna Felden - Treasurer (replaces Ivan Langella)
# - Domenico Lahaye - Secretary (second term)
# - Christine Bertrand - Outreach (replace Xiaocheng Ming)
#
# ### 2/ Registration of new board members at the Kamer van Koophandel
#
# To do:
# - Anna: await news on registration;
# - Stefano and Christine: register online using DIGID at the [Kamer van Koophandel (kvk)](https://www.kvk.nl).
#
# ### 3/ Securing NVV Financial Reserves
#
# - Suggestion is to invest approximately EUR 50k (fifty thousand) in long term fund to protect against devaluation.
# Impact on taxes (to be paid to the Dutch state) and management of the fund (to be paid to ING Bank) to be investigated further.
# - The board has met ING bank two times already and gathered all the relevant information (on 22nd December 2025  and on 19th January 2026)
#
# To do: Stefanio will take to tax advisor in February. Anna pays EUR 200 (two hundred) for consultancy with tax advisor.
#
# ### 4/ Combura2026 - 2027
#
# - Book the venue 1 or 2 years in advance.
# - Possible location (?): Shell Amsterdam or Shell De Haag buildings. This would allow cost optimization allowing resources to be used for discounts for the Hotel and discounted rates for undergraduates and first time guests.
# - be advised of higher fees for accommodation (unless accomodation in e.g. Amsterdam Noord can be arranged?).
#
# Anna:
# - strong preference for neutral location for Combura;
# - website for [registration for registration for Combura2025](https://www.aanmelder.nl/combura2025).
#
# Donmenico:
# - does this website entirely replace [combura.nl](https://www.combura.nl)? Information on best master thesis award and best poster award seems to be missing
# - what are the fees to be paid to Aanmelder.nl?
#
# To do: collect list of attendees of past editions;
#
# ### 5/ Visibility: Website NNV and Website Combura
#
# Stefano:
# - Merge Combura and NVV websites with one single website, the website will be pretty much static but with a news section that is linked with our LinkedIn page. The Combura part will update every year with the new meeting registration and information.
# - If we can monetize the website visits, then we will do the other way around (meaning that the website will be the source of all updates and the LinkedIn page will share the link to our website).
# - Christine will look to solutions that are suitable for our needs for the website. Best solution would be to use a professional contractor to develop the main website while we can use an app to adjust and update the news and any other minor changes ourselves without needing to pay anybody.
# - Starting from 2026 registration to Combura, we will add to the registration page a box to tick to allow us to send the email reminders for the next years Combura meetings and events.
# - Open a Wikipedia page that will talk about the history of NVV, the link to [Dutch Section of the Combustion Institute (DSCI)](http://www.combustioninstitute.nl) and [International Flame Research Foundation (IFRF)](https://ifrf.net), the historical board members, and some success stories.
#
# Domenico
# - Possibly no need for a professional contractor in case that we wish to establish the content of the website first
#
# ### 6/ Visibility: Industrial Membership of NVV
#
# - list potentially new industrial members;
# - list what NVV can offer to existing and new members compared to other organizations like DSCI and IFRF;
# - step away from the idea to keep the research in house. We can use open domain tools because this will help NVV to support more industry projects;
# - NVV can sponsor two projects at a time. The project MetalPower ended in 2025. The project DYNAF will end in 2026. We have space to sponsor new projects again in 2026;
#
# ### 7/ How to position link with Dutch Section of the Combustion Institute, IFRF, other national committees, ASME and other parties?
#
# - We wish to keep good relationship with both organizations and we want to use this good relationship to attract new members and guests to our events;
# - With regards to IFRF: We prefer to remain associated to IFRF, as long as one member is there, we can be considered associated. We will keep the annual fee payment separated. We can ask IFRF to select the best poster of the year and present it at Combura;
# - How to take advantage of each others networks and activities? How to be complementary to existing initiatives (e.g. TOTEM, INFUB)?
#
# ### 8/ Forthcoming NVV Board Meeting
#
# To do: establish date and location (end of February after we meet with the accountant to ask for advice on the taxes related to the bank investment).
#
# ## Vademecum Combura (in progress)
#
# ### 1/ Organizational comitee (including Annual NVV Board Meeting)
# 1. infrastructure (room, projector-screen, audiovisual equipment, online access and catering) for annual NVV members meeting;
# 2. infrastructure (room, projector-screen and audiovisual equipment) for plenary lectures;
# 3. infrastructure (room, projector-screen and audiovisual equipment) for parallel lectures;
# 4. infrastructure (room) for lunch and closing drinks;
#
# ### 2/ Scientific comitee
# 1. invitation invited speakers
# 2. best master thesis award (jury, award)
# 3. best poster price (jury, award)
#
# ## Agenda Annual Board Meeting (in progress)
# 1. opening;
# 2. audit annual overview of finances;
# 3. this year and next year Combura;
# 4. closure;
